# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# from collections import Counter
import warnings
warnings.filterwarnings('ignore')

# %%
x = np.linspace(-20,20,100)
y = np.sin(x)/x
plt.plot(x,y);

# %%
x=np.linspace(1,10,11)
y = x **2
fig,ax=plt.subplots()
ax.plot(x,y);

# %%
f,(ax1, ax2) = plt.subplots(1,2, sharey= True)
ax1.plot(x,y)
ax1.set_title("Sharing Y axis")
ax2. scatter(x,y)

# %%
f, ax = plt.subplots(1,2, sharey=True)
ax[0].plot(x,y)
ax[1].scatter(x,y)

# %%
#df0 = pd.read_csv("PoliceKillingsUS.csv", encoding = "UTF-8")

# %%
df0 = pd.read_csv("PoliceKillingsUS.csv", encoding = "windows-1252")
df = df0.copy()

# %%
df
# Out:
#         id                name      date   manner_of_death       armed   age  \
# 0        3          Tim Elliot  02/01/15              shot         gun  53.0
# 1        4    Lewis Lee Lembke  02/01/15              shot         gun  47.0
# 2        5  John Paul Quintero  03/01/15  shot and Tasered     unarmed  23.0
# 3        8     Matthew Hoffman  04/01/15              shot  toy weapon  32.0
# 4        9   Michael Rodriguez  04/01/15              shot    nail gun  39.0
# ...    ...                 ...       ...               ...         ...   ...
# 2530  2822    Rodney E. Jacobs  28/07/17              shot         gun  31.0
# 2531  2813               TK TK  28/07/17              shot     vehicle   NaN
# 2532  2818  Dennis W. Robinson  29/07/17              shot         gun  48.0
# 2533  2817       Isaiah Tucker  31/07/17              shot     vehicle  28.0
# 2534  2815        Dwayne Jeune  31/07/17              shot       knife  32.0
#
#      gender race           city state  signs_of_mental_illness threat_level  \
# 0         M    A        Shelton    WA                     True       attack
# 1         M    W          Aloha    OR                    False       attack
# 2         M    H        Wichita    KS                    False        other
# 3         M    W  San Francisco    CA                     True       attack
# 4         M    H          Evans    CO                    False       attack
# ...     ...  ...            ...   ...                      ...          ...
# 2530      M  NaN    Kansas City    MO                    False       attack
# 2531      M  NaN    Albuquerque    NM                    False       attack
# 2532      M  NaN          Melba    ID                    False       attack
# 2533      M    B        Oshkosh    WI                    False       attack
# 2534      M    B       Brooklyn    NY                     True       attack
#
#              flee  body_camera
# 0     Not fleeing        False
# 1     Not fleeing        False
# 2     Not fleeing        False
# 3     Not fleeing        False
# 4     Not fleeing        False
# ...           ...          ...
# 2530  Not fleeing        False
# 2531          Car        False
# 2532          Car        False
# 2533          Car         True
# 2534  Not fleeing        False
#
# [2535 rows x 14 columns]

# %%
df.race.value_counts().values
# Out:
# array([1201,  618,  423,   39,   31,   28])

# %%
fig, ax = plt.subplots()
ax.bar(df.race.value_counts().index,df.race.value_counts().values)
# Out:
# <BarContainer object of 6 artists>

# %%
fig, ax = plt.subplots()
ax.bar(df.race.value_counts().index,df.race.value_counts().values)
plt.title("figıure raxe")
for i in ax.patches:
    ax.annotate((a.get_height()), (a.get_hight() + 0.35))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/7c/_zsfbv097zx2237y5krgcq000000gn/T/ipykernel_729/3012383893.py in <module>
#       3 plt.title("figıure raxe")
#       4 for i in ax.patches:
# ----> 5     ax.annotate((a.get_height()), (a.get_hight() + 0.35))
#
# NameError: name 'a' is not defined

# %%
ax.patches[1].get_x()
# Out:
# 0.6

# %%
ax.patches[1].get_height()
# Out:
# 618

# %%
pandas

# %%
df.race.value_counts()
# Out:
# W    1201
# B     618
# H     423
# A      39
# N      31
# O      28
# Name: race, dtype: int64

# %%
fig, ax = plt.subplots()

df.race.value_counts().plot(kind = "bar", ax = ax)
ax.set_title("race", fontsize = 15,color = "darkmagenta")
ax.bar_label(ax.containers[0], color = "r", size = 10,label_type = "edge", padding = 10)
# Out:
# [Text(0, 10, '1201'),
#  Text(0, 10, '618'),
#  Text(0, 10, '423'),
#  Text(0, 10, '39'),
#  Text(0, 10, '31'),
#  Text(0, 10, '28')]

# %%
fig, ax = plt.subplots()

df.race.value_counts().plot(kind="bar", ax=ax)
ax.set_title("race Distribution", fontsize=15)

ax.bar_label(ax.containers[0], color="red",
            size=10,
            label_type="center",
            padding=10)

ax.set(facecolor = "powderblue")
fig.set_facecolor("plum");

# %%
x = df.race.value_counts().index
y = df.race.value_counts().values
plt.figure(figsize = (8,6), facecolor= "pink")
plt.bar(x,y)
plt.title("race distrubu")
# Out:
# Text(0.5, 1.0, 'race distrubu')

# %%
x = df.race.value_counts().index
y = df.race.value_counts().values
plt.figure(figsize = (8,6), facecolor= "pink")
plt.bar(x,y)
plt.title("race distrubu")
for i in range(len(x)):

# %%
df2 = sns.load_dataset("diamonds")
print(df2.info())
df2.sample(20)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  category
#  2   color    53940 non-null  category
#  3   clarity  53940 non-null  category
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: category(3), float64(6), int64(1)
# memory usage: 3.0 MB
# None
#        carat        cut color clarity  depth  table  price     x     y     z
# 48022   0.53      Ideal     G     VS1   61.3   57.0   1922  5.18  5.22  3.19
# 23574   1.32      Ideal     G     VS1   61.7   56.0  11584  7.04  7.07  4.35
# 51071   0.71  Very Good     F     SI1   61.9   56.0   2333  5.67  5.70  3.52
# 37463   0.42    Premium     G     VS1   60.6   58.0    984  4.95  4.82  2.96
# 24601   2.02  Very Good     J     SI1   63.5   60.0  12915  7.98  7.93  5.05
# 25392   2.22    Premium     I     SI1   62.7   58.0  14095  8.33  8.28  5.21
# 455     0.63      Ideal     F    VVS2   61.5   56.0   2817  5.48  5.52  3.38
# 41341   0.42      Ideal     H      IF   61.9   56.0   1216  4.79  4.81  2.97
# 39397   0.41      Ideal     G    VVS2   61.0   57.0   1076  4.80  4.78  2.92
# 42260   0.49       Good     F     VS1   58.5   61.5   1294  5.18  5.21  3.04
# 22671   1.22  Very Good     F    VVS2   60.7   62.0  10719  6.81  6.84  4.14
# 3848    0.70  Very Good     D     VS1   61.6   58.0   3477  5.67  5.73  3.51
# 16578   1.06      Ideal     H     VS2   62.3   53.0   6619  6.58  6.56  4.09
# 40159   0.35    Premium     G      IF   62.2   58.0   1116  4.52  4.45  2.79
# 50120   0.73      Ideal     G     SI2   61.8   56.0   2210  5.76  5.80  3.57
# 53443   0.75       Good     E     SI1   63.4   57.0   2674  5.75  5.77  3.65
# 53909   0.70  Very Good     E     SI1   62.7   59.0   2753  5.63  5.67  3.54
# 29418   0.38    Premium     I     VS1   61.3   60.0    700  4.62  4.65  2.84
# 26105   1.02    Premium     D      IF   61.5   60.0  15370  6.52  6.45  3.99
# 5269    1.02  Very Good     J     VS2   59.3   58.0   3796  6.56  6.62  3.91

# %%
df2.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
df2.cut.value_counts()
# Out:
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: cut, dtype: int64

# %%
df2.cut.value_counts(ascending=True)[:3]
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Name: cut, dtype: int64

# %%
least = df2.cut.value_counts(ascending=True)[:3]
least
# Out:
# Fair          1610
# Good          4906
# Very Good    12082
# Name: cut, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.bar(x = least.index, height=least.values)
ax.bar_label(ax.containers[0],color = "pink")
# Out:
# [Text(0, 0, '1610'), Text(0, 0, '4906'), Text(0, 0, '12082')]

# %%
fig, ax = plt.subplots(figsize=(8,5))
least.plot(kind = "bar")
ax.bar(x = least.index, height=least.values)
# Out:
# <BarContainer object of 3 artists>

# %%
kategori = df2.cut.value_counts(ascending=True, normalize = True)[:3].index

# %%
value = df2.cut.value_counts(ascending=True, normalize = True)[:3]*100

# %%
fig, ax = plt.subplots(figsize=(8,5))
ax.pie(x= value,autopct =" %.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc50caccbb0>,
#   <matplotlib.patches.Wedge at 0x7fc50cac1430>,
#   <matplotlib.patches.Wedge at 0x7fc50cac15b0>],
#  [Text(1.0595700455274055, 0.29548488729722244, ''),
#   Text(0.21653522772474842, 1.0784769330654187, ''),
#   Text(-0.49827968079155105, -0.9806718919752264, '')],
#  [Text(0.5779472975604029, 0.16117357488939404, ' 8.7%'),
#   Text(0.11811012421349913, 0.5882601453084101, ' 26.4%'),
#   Text(-0.27178891679539147, -0.5349119410773961, ' 65.0%')])

# %%
df2.sample(5)
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 1578    0.71    Ideal     G     SI1   61.9   56.0   3007  5.73  5.76  3.55
# 29922   0.32    Ideal     E     VS1   61.1   56.0    713  4.42  4.45  2.71
# 38154   0.36  Premium     E     VS2   62.0   58.0   1013  4.56  4.54  2.82
# 52760   0.62    Ideal     D     VS1   61.0   57.0   2562  5.51  5.54  3.37
# 33121   0.31    Ideal     E    VVS2   61.0   56.0    816  4.39  4.43  2.69

# %%
plt.boxplot(df2.price,vert = False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc51a1ff100>,
#   <matplotlib.lines.Line2D at 0x7fc51a1ff3d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc51a1ff6a0>,
#   <matplotlib.lines.Line2D at 0x7fc51a1ff970>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc52bd52df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc51a1ffc40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc51a1fff10>],
#  'means': []}

# %%
fig, ax = plt.subplots()
ax = df2.price.plot(kind = "box", colormap = "coolwarm")

# %%
df2.price.plot(kind = "box", colormap = "coolwarm")
# Out:
# <AxesSubplot:>

# %%
plt.hist(df2.price, bins = 10)
# Out:
# (array([25335.,  9328.,  7393.,  3878.,  2364.,  1745.,  1306.,  1002.,
#           863.,   726.]),
#  array([  326. ,  2175.7,  4025.4,  5875.1,  7724.8,  9574.5, 11424.2,
#         13273.9, 15123.6, 16973.3, 18823. ]),
#  <BarContainer object of 10 artists>)

# %%
df2.price.quantile([0,0.25,0.5,0.75,1])
# Out:
# 0.00      326.00
# 0.25      950.00
# 0.50     2401.00
# 0.75     5324.25
# 1.00    18823.00
# Name: price, dtype: float64

# %%
df2["price_cat"]= df2.price.apply(lambda x : "high" if x >=5324 else ("medium" if x > 950 and x <=5324 else "low"))

# %%
df2.price_cat.value_counts()
# Out:
# medium    26960
# low       13490
# high      13490
# Name: price_cat, dtype: int64
